# %%
int Num = 100
strData = "안녕"
print(int Num + strData)
# Out:
#   File "<ipython-input-1-e1306fd0581c>", line 1
#     int Num = 100
#         ^
# SyntaxError: invalid syntax

# %%
intnum=100
str(intnum)
strData="안녕"
type(num)
print(strData+str(intnum))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-fe7d50e387cc> in <module>
#       2 str(intnum)
#       3 strData="안녕"
# ----> 4 type(num)
#       5 print(strData+str(intnum))
#
# NameError: name 'num' is not defined
